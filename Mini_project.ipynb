# %% [markdown]
# <a href="https://colab.research.google.com/github/Mukthadevi/Mini-project/blob/main/Mini_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from skimage.transform import resize
from skimage.io import imread
import os

# %%
 
target = []
images = [] 
flat_data = []   

DATADIR = '/content/drive/My Drive/ DS'
CAT  = ['sunflower','red rose',]

for category in CAT:
  class_num = CAT .index(category)
  path = os.path.join(DATADIR,category)
  for img in os.listdir(path):
    img_array = imread(os.path.join(path,img))
    img_resized = resize(img_array,(150,150,3))
    flat_data.append(img_resized.flatten())
    images.append(img_resized)
    target.append(class_num)

target = np.array(target)
images = np.array(images)
flat_data = np.array(flat_data)

# %%
df = pd.DataFrame(flat_data)
df['Target'] = target
df
# Out:
#            0         1         2  ...     67498     67499  Target
# 0   0.262745  0.447059  0.800000  ...  0.313065  0.073863       0
# 1   0.000000  0.278431  0.650980  ...  0.537255  0.835294       0
# 2   0.422706  0.466392  0.260471  ...  0.279882  0.104471       0
# 3   0.504706  0.479333  0.438275  ...  0.056627  0.019843       0
# 4   0.483665  0.552405  0.674745  ...  0.488868  0.013647       0
# 5   0.384314  0.717647  0.933059  ...  0.218928  0.242458       0
# 6   0.419608  0.564706  0.737255  ...  0.207843  0.153516       0
# 7   0.408275  0.576902  0.714157  ...  0.124405  0.000000       0
# 8   0.696287  0.519556  0.087791  ...  0.133333  0.000000       0
# 9   0.329987  0.623529  0.890196  ...  0.244144  0.059244       0
# 10  1.000000  1.000000  0.992157  ...  0.203922  0.184314       0
# 11  0.418856  0.292752  0.095820  ...  0.081490  0.006980       0
# 12  0.782843  0.570343  0.042647  ...  0.177696  0.110539       0
# ...

# %%
df.loc[(df['Target'] == 0) ,
         'Target']= 'Sunflower'        
df.loc[(df['Target'] == 1) ,
         'Target']= 'Red rose'
 
df
# Out:
#            0         1         2  ...     67498     67499     Target
# 0   0.262745  0.447059  0.800000  ...  0.313065  0.073863  Sunflower
# 1   0.000000  0.278431  0.650980  ...  0.537255  0.835294  Sunflower
# 2   0.422706  0.466392  0.260471  ...  0.279882  0.104471  Sunflower
# 3   0.504706  0.479333  0.438275  ...  0.056627  0.019843  Sunflower
# 4   0.483665  0.552405  0.674745  ...  0.488868  0.013647  Sunflower
# 5   0.384314  0.717647  0.933059  ...  0.218928  0.242458  Sunflower
# 6   0.419608  0.564706  0.737255  ...  0.207843  0.153516  Sunflower
# 7   0.408275  0.576902  0.714157  ...  0.124405  0.000000  Sunflower
# 8   0.696287  0.519556  0.087791  ...  0.133333  0.000000  Sunflower
# 9   0.329987  0.623529  0.890196  ...  0.244144  0.059244  Sunflower
# 10  1.000000  1.000000  0.992157  ...  0.203922  0.184314  Sunflower
# 11  0.418856  0.292752  0.095820  ...  0.081490  0.006980  Sunflower
# 12  0.782843  0.570343  0.042647  ...  0.177696  0.110539  Sunflower
# ...

# %%
x = df.iloc[:,0:67500].values
y = df.loc[:,'Target'].values

# %%
x.shape
# Out:
# (29, 67500)

# %%
y
# Out:
# array(['Sunflower', 'Sunflower', 'Sunflower', 'Sunflower', 'Sunflower',
#        'Sunflower', 'Sunflower', 'Sunflower', 'Sunflower', 'Sunflower',
#        'Sunflower', 'Sunflower', 'Sunflower', 'Sunflower', 'Red rose',
#        'Red rose', 'Red rose', 'Red rose', 'Red rose', 'Red rose',
#        'Red rose', 'Red rose', 'Red rose', 'Red rose', 'Red rose',
#        'Red rose', 'Red rose', 'Red rose', 'Red rose'], dtype=object)

# %%
df.shape
# Out:
# (29, 67501)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,random_state=1)
xtrain.shape
# Out:
# (21, 67500)

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=4,metric='euclidean')
model.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=None, n_neighbors=4, p=2,
#                      weights='uniform')

# %%
pred = model.predict(xtest)
pred
# Out:
# array(['Red rose', 'Red rose', 'Red rose', 'Red rose', 'Red rose',
#        'Red rose', 'Sunflower', 'Red rose'], dtype=object)

# %%
ytest
# Out:
# array(['Red rose', 'Red rose', 'Red rose', 'Red rose', 'Red rose',
#        'Red rose', 'Sunflower', 'Sunflower'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(pred,ytest)
# Out:
# 0.875
